# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import shapely
import difflib # string differences
import numpy as np
import matplotlib

# %matplotlib inline

# %%
print(shapely.__version__)
print(np.__version__)
print(matplotlib.__version__)
print(gpd.__version__)
print(pd.__version__)
# Out:
# 1.6.4.post2
# 1.16.2
# 3.0.3
# 0.4.0+26.g9e584cc
# 0.24.2

# %%
air_pollution_rates = pd.read_csv("preprocessed_data/death-rates-from-ambient-particulate-air-pollution.csv")
air_pollution_exposure = pd.read_csv("preprocessed_data/PM25-air-pollution.csv")
countries = gpd.read_file("../../assets/data/countries.geo.json")

# %%
air_pollution_rates.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate) (deaths per 100,000)
# 0                                          46.446589
# 1                                          46.033841
# 2                                          44.243766
# 3                                          44.440148
# 4                                          45.594328

# %%
air_pollution_exposure.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1995
# 2  Afghanistan  AFG  2000
# 3  Afghanistan  AFG  2005
# 4  Afghanistan  AFG  2010
#
#    PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) (micrograms per cubic meter)
# 0                                          60.936690
# 1                                          56.136628
# 2                                          56.092028
# 3                                          43.234032
# 4                                          46.536809

# %%
### INITIAL SUBSETTING
air_pollution_rates = air_pollution_rates[air_pollution_rates.Year.apply(lambda yr: int(yr) >= 1990)].reset_index(drop=True)
air_pollution_rates.columns = ["country", "code","year", "deaths_per100000"]
# air_pollution_rates.to_csv("preprocessed_data/death-rates-from-ambient-particulate-air-pollution.csv",index=False)

air_pollution_exposure = air_pollution_exposure[air_pollution_exposure.Year.apply(lambda yr: int(yr) >= 1990)].reset_index(drop=True)
air_pollution_exposure.columns = ["country", "code","year", "pm25_exposure"]
# air_pollution_exposure.to_csv("preprocessed_data/PM25-air-pollution.csv",index=False)

# %%
air_pollution = air_pollution_rates.merge(air_pollution_exposure, how='left')

# %%
air_pollution.head()
# Out:
#        country code  year  deaths_per100000  pm25_exposure
# 0  Afghanistan  AFG  1990         46.446589       60.93669
# 1  Afghanistan  AFG  1991         46.033841            NaN
# 2  Afghanistan  AFG  1992         44.243766            NaN
# 3  Afghanistan  AFG  1993         44.440148            NaN
# 4  Afghanistan  AFG  1994         45.594328            NaN

# %%
## Plotting a centroid
fig, ax = plt.subplots(1)
countries[countries.name == "France"].plot(ax=ax)
countries[countries.name == "France"].centroid.plot(color='red', ax=ax)

# %%
countries['centroid'] = countries.geometry.apply(lambda cn: cn.centroid)

# %%
countries.centroid.plot()

# %%
## make a set of the countries to look at differences
airpol_countries = set(air_pollution.country.unique())
cn_countries = set(countries.name.unique())

cn_countries_diff = cn_countries.difference(airpol_countries)
airpol_diff = airpol_countries.difference(cn_countries)

print(cn_countries_diff)
print(airpol_diff)
# Out:
# {'United Republic of Tanzania', 'Northern Cyprus', 'French Southern and Antarctic Lands', 'United States of America', 'The Bahamas', 'Antarctica', 'West Bank', 'French Guiana', 'Ivory Coast', 'Somaliland', 'New Caledonia', 'Kosovo', 'Republic of Serbia', 'Guinea Bissau', 'Western Sahara', 'Republic of the Congo', 'Falkland Islands', 'Democratic Republic of the Congo', 'East Timor'}
# {'Tonga', 'North Africa and Middle East', 'High-income', 'Southern Latin America', 'Oceania', 'Cape Verde', 'Central Europe, Eastern Europe, and Central Asia', 'Bahamas', 'Antigua and Barbuda', 'Central Latin America', "Cote d'Ivoire", 'Middle SDI', 'Northern Mariana Islands', 'Saint Lucia', 'Comoros', 'England', 'Bahrain', 'Central Asia', 'Scotland', 'Seychelles', 'High-income Asia Pacific', 'Sao Tome and Principe', 'Andorra', 'World', 'Maldives', 'Samoa', 'South Asia', 'Low-middle SDI', 'United States', 'Kiribati', 'Caribbean', 'Southeast Asia, East Asia, and Oceania', 'Guinea-Bissau', 'Micronesia (country)', 'United States Virgin Islands', 'Western Europe', 'Tropical Latin America', 'Mauritius', 'Grenada', 'Palestine', 'Marshall Islands', 'Eastern Sub-Saharan Africa', 'Dominica', 'Wales', 'Latin America and Caribbean', 'Southeast Asia', 'Southern Sub-Saharan Africa', 'Andean Latin America', 'Western Sub-Saharan Africa', 'High SDI', 'Timor', 'Congo', 'Tanzania', 'Low SDI', 'Eastern Europe', 'Australasia', 'American Samoa', 'Barbados', 'Serbia', 'Singapore', 'Democratic Republic of Congo', 'High-middle SDI', 'East Asia', 'Guam', 'Saint Vincent and the Grenadines', 'Sub-Saharan Africa', 'North America', 'Central Sub-Saharan Africa', 'Northern Ireland', 'Central Europe'}

# %%
## LOOK at country names from each dataset which are similar in string distance
to_change = {}
for airpoldiff in airpol_diff:
    for cndiff in cn_countries_diff:
        try:
            the_ratio = difflib.SequenceMatcher(None, cndiff, airpoldiff).ratio()
            if the_ratio > 0.7:
                print("'%s' should be changed to '%s'. Similarity score = %s" % (airpoldiff, cndiff, round(the_ratio, 3)))
                to_change["{}".format(cndiff)] = airpoldiff
        except:
            pass
# Out:
# 'Bahamas' should be changed to 'The Bahamas'. Similarity score = 0.778
# 'United States' should be changed to 'United States of America'. Similarity score = 0.703
# 'Guinea-Bissau' should be changed to 'Guinea Bissau'. Similarity score = 0.923
# 'Democratic Republic of Congo' should be changed to 'Democratic Republic of the Congo'. Similarity score = 0.933

# %%
## user prompt to change country nanes
for chng in to_change.items():
    change = input("Do you want to change %s to %s" % (chng[0], chng[1]))
    if change.lower() == "y":
        countries.replace(chng[0], chng[1], inplace=True)
        print("ITEM CHANGED")
    else:
        print("item not changed")

## DO NOT CHANGE FALKLAND ISLANDS
# Out:
# Do you want to change The Bahamas to Bahamasy
# ITEM CHANGED
# Do you want to change United States of America to United Statesy
# ITEM CHANGED
# Do you want to change Guinea Bissau to Guinea-Bissauy
# ITEM CHANGED
# Do you want to change Democratic Republic of the Congo to Democratic Republic of Congoy
# ITEM CHANGED

# %%
## NOTES:
## ADD back Hong Kong and Singapore (manually get centroid)
## Singapore 1.290270, 103.851959.
## Hong Kong 22.3193° N, 114.1694° E

# %%
## merge air pollution
air_pollution = air_pollution.merge(countries, left_on="country", right_on="name",how="left")
## then drop uneeded columns
air_pollution.drop(['geometry'], axis=1, inplace=True)
air_pollution.rename(index=str, columns={"centroid": "geometry"},inplace=True)

# %%
air_pollution.dropna(subset=['geometry'],inplace=True)
air_pollution.reset_index(drop=True, inplace=True)

# %%
air_pollution_rates_gdf = gpd.GeoDataFrame(air_pollution, geometry="geometry")

# %%
for ind in air_pollution_rates_gdf.iloc[np.where(air_pollution_rates_gdf.country == "Singapore")].index:
    air_pollution_rates.at[ind,'geometry'] = shapely.geometry.Point(103.851959, 1.290270)
for ind in air_pollution_rates_gdf.iloc[np.where(air_pollution_rates_gdf.country == "Hong Kong")].index:
    air_pollution_rates.at[ind,'geometry'] = shapely.geometry.Point(114.1694, 22.3193)

# %%
air_pollution_rates_gdf.country.value_counts()
# Out:
# Myanmar                   28
# Benin                     28
# Luxembourg                28
# Albania                   28
# Madagascar                28
# Poland                    28
# Philippines               28
# Iran                      28
# Pakistan                  28
# Oman                      28
# Latvia                    28
# Burundi                   28
# Botswana                  28
# Chile                     28
# Equatorial Guinea         28
# Tajikistan                28
# Lebanon                   28
# Sudan                     28
# Zimbabwe                  28
# Austria                   28
# Angola                    28
# Portugal                  28
# Malta                     28
# Burkina Faso              28
# Panama                    28
# Turkmenistan              28
# Mozambique                28
# Denmark                   28
# Bahamas                   28
# Moldova                   28
#                           ..
# Brunei                    28
# Belarus                   28
# Dominican Republic        28
# Malawi                    28
# Costa Rica                28
# Guinea-Bissau             28
# Tunisia                   28
# Bosnia and Herzegovina    28
# Liberia                   28
# Ireland                   28
# Eritrea                   28
# Papua New Guinea          28
# Peru                      28
# Netherlands               28
# Malaysia                  28
# Yemen                     28
# Vanuatu                   28
# Zambia                    28
# Kuwait                    28
# Niger                     28
# Fiji                      28
# South Africa              28
# Cyprus                    28
# Mali                      28
# Saudi Arabia              28
# Gabon                     28
# Greenland                 28
# Uganda                    28
# France                    28
# Brazil                    28
# Name: country, Length: 165, dtype: int64

# %%
air_pollution_rates_gdf
# Out:
#           country code  year  deaths_per100000  pm25_exposure   id  \
# 0     Afghanistan  AFG  1990         46.446589      60.936690  AFG
# 1     Afghanistan  AFG  1991         46.033841            NaN  AFG
# 2     Afghanistan  AFG  1992         44.243766            NaN  AFG
# 3     Afghanistan  AFG  1993         44.440148            NaN  AFG
# 4     Afghanistan  AFG  1994         45.594328            NaN  AFG
# 5     Afghanistan  AFG  1995         45.367141      56.136628  AFG
# 6     Afghanistan  AFG  1996         45.383591            NaN  AFG
# 7     Afghanistan  AFG  1997         45.585062            NaN  AFG
# 8     Afghanistan  AFG  1998         44.837490            NaN  AFG
# 9     Afghanistan  AFG  1999         45.325501            NaN  AFG
# 10    Afghanistan  AFG  2000         45.034004      56.092028  AFG
# 11    Afghanistan  AFG  2001         45.319383            NaN  AFG
# 12    Afghanistan  AFG  2002         45.373511            NaN  AFG
# 13    Afghanistan  AFG  2003         46.533601            NaN  AFG
# 14    Afghanistan  AFG  2004         46.230592            NaN  AFG
# 15    Afghanistan  AFG  2005         46.139371      43.234032  AFG
# 16    Afghanistan  AFG  2006         46.319416            NaN  AFG
# 17    Afghanistan  AFG  2007         47.012086            NaN  AFG
# 18    Afghanistan  AFG  2008         46.736896            NaN  AFG
# 19    Afghanistan  AFG  2009         46.833372            NaN  AFG
# 20    Afghanistan  AFG  2010         46.733269      46.536809  AFG
# 21    Afghanistan  AFG  2011         48.290188      50.483960  AFG
# 22    Afghanistan  AFG  2012         48.148226      50.653945  AFG
# 23    Afghanistan  AFG  2013         46.376090      50.968831  AFG
# 24    Afghanistan  AFG  2014         45.193898      49.036091  AFG
# 25    Afghanistan  AFG  2015         47.334537      62.080234  AFG
# 26    Afghanistan  AFG  2016         44.826196      62.854857  AFG
# 27    Afghanistan  AFG  2017         45.737662            NaN  AFG
# 28        Albania  ALB  1990         23.483019      17.796006  ALB
# 29        Albania  ALB  1991         24.263080            NaN  ALB
# ...           ...  ...   ...               ...            ...  ...
# 4590       Zambia  ZMB  2016         21.534921      30.550295  ZMB
# 4591       Zambia  ZMB  2017         21.537253            NaN  ZMB
# 4592     Zimbabwe  ZWE  1990         17.985921      26.273116  ZWE
# 4593     Zimbabwe  ZWE  1991         17.758366            NaN  ZWE
# 4594     Zimbabwe  ZWE  1992         18.074836            NaN  ZWE
# 4595     Zimbabwe  ZWE  1993         18.409361            NaN  ZWE
# 4596     Zimbabwe  ZWE  1994         19.048994            NaN  ZWE
# 4597     Zimbabwe  ZWE  1995         19.939993      24.818500  ZWE
# 4598     Zimbabwe  ZWE  1996         20.752559            NaN  ZWE
# 4599     Zimbabwe  ZWE  1997         22.178813            NaN  ZWE
# 4600     Zimbabwe  ZWE  1998         24.537421            NaN  ZWE
# 4601     Zimbabwe  ZWE  1999         26.969706            NaN  ZWE
# 4602     Zimbabwe  ZWE  2000         29.435779      25.088495  ZWE
# 4603     Zimbabwe  ZWE  2001         30.981992            NaN  ZWE
# 4604     Zimbabwe  ZWE  2002         32.937889            NaN  ZWE
# 4605     Zimbabwe  ZWE  2003         33.136802            NaN  ZWE
# 4606     Zimbabwe  ZWE  2004         33.474990            NaN  ZWE
# 4607     Zimbabwe  ZWE  2005         32.994156      25.423200  ZWE
# 4608     Zimbabwe  ZWE  2006         32.996463            NaN  ZWE
# 4609     Zimbabwe  ZWE  2007         32.542073            NaN  ZWE
# 4610     Zimbabwe  ZWE  2008         31.831643            NaN  ZWE
# 4611     Zimbabwe  ZWE  2009         31.157802            NaN  ZWE
# 4612     Zimbabwe  ZWE  2010         29.963243      22.480427  ZWE
# 4613     Zimbabwe  ZWE  2011         28.927819      23.397666  ZWE
# 4614     Zimbabwe  ZWE  2012         28.101919      23.359478  ZWE
# 4615     Zimbabwe  ZWE  2013         27.589603      23.448376  ZWE
# 4616     Zimbabwe  ZWE  2014         26.760618      23.072327  ZWE
# 4617     Zimbabwe  ZWE  2015         25.715415      24.371786  ZWE
# 4618     Zimbabwe  ZWE  2016         25.643570      24.513035  ZWE
# 4619     Zimbabwe  ZWE  2017         26.166182            NaN  ZWE
#
#              name                                      geometry
# 0     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 1     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 2     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 3     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 4     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 5     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 6     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 7     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 8     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 9     Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 10    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 11    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 12    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 13    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 14    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 15    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 16    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 17    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 18    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 19    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 20    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 21    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 22    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 23    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 24    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 25    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 26    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 27    Afghanistan   POINT (66.08669017344639 33.85639924331851)
# 28        Albania   POINT (20.03242638605213 41.14135336776871)
# 29        Albania   POINT (20.03242638605213 41.14135336776871)
# ...           ...                                           ...
# 4590       Zambia  POINT (27.72759183970333 -13.39506758615823)
# 4591       Zambia  POINT (27.72759183970333 -13.39506758615823)
# 4592     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4593     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4594     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4595     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4596     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4597     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4598     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4599     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4600     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4601     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4602     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4603     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4604     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4605     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4606     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4607     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4608     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4609     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4610     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4611     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4612     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4613     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4614     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4615     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4616     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4617     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4618     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
# 4619     Zimbabwe  POINT (29.78854831417214 -18.90698790433024)
#
# [4620 rows x 8 columns]

# %%
air_pollution_rates_gdf.to_file("../../assets/data/airpollutionDeaths.geojson", driver="GeoJSON")

# %%
## create histogram plot

# %%
plt.rcParams['figure.figsize'] = (8,4)
air_pollution_rates_gdf.deaths_per100000.hist(bins=np.arange(0,200,10), color="#AB1C1C", alpha=.5)
air_pollution_rates_gdf.pm25_exposure.hist(bins=np.arange(0,200,10), color="#0A7D2B", alpha=.5)
plt.legend(["PM2.5 Death Rate per 100,000", "PM2.5 Exposure"])
plt.ylabel("Count", size=16)
plt.xlabel("Value", size=16)
for xval in [20,40,60,80,100]:
    plt.vlines(x=xval,ymin=0, ymax=1400, colors='red', linestyles='--', alpha=.6)
plt.xlim(0,200)
plt.ylim(0,1400)
plt.title("Histogram comparing PM2.5 Death Rate and Exposure", size=18)
plt.savefig("../../assets/img/histogram_pm25.png", bbox_inches='tight')
